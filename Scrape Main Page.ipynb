# %%
#Goal: pull url's from EE main page and click throughh them 

import requests
import lxml.html as lh
import pandas as pd
import numpy as np
import pandas as pd

from urllib.request import urlopen
from bs4 import BeautifulSoup
import codecs
from splinter import Browser
from bs4 import BeautifulSoup
import time

# %%
#Path to chromedriver
def init_browser():
    # @NOTE: Replace the path with your actual path to the chromedriver
    executable_path = {"executable_path": "chromedriver"}
    return Browser("chrome", **executable_path, headless=False)

# %%
#Scrape Event listings
def scrape():
    browser = init_browser()
    listings = {}

    url = "https://evententries.com/#LiveScores"
    browser.visit(url)
    time.sleep(1)
    html = browser.html
    soup = BeautifulSoup(html, "html.parser")

#     listings["headline"] = soup.find("a", class_="result-title").get_text()
#     listings["price"] = soup.find("span", class_="result-price").get_text()
#     listings["hood"] = soup.find("span", class_="result-hood").get_text()
    return soup

# %%
soup = scrape()

# %%
#Html for main page 
print(soup)
# Out:
# <html><head>
# <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
# <meta content="width=device-width,initial-scale=1,maximum-scale=1,minimum-scale=1,user-scalable=no" name="viewport"/>
# <meta content="no-cache, no-store, must-revalidate" http-equiv="Cache-Control"/>
# <meta content="no-cache" http-equiv="Pragma"/>
# <meta content="0" http-equiv="Expires"/>
# <!-- -->
# <!-- Consider inlining CSS to reduce the number of requested files -->
# <!-- -->
# <link href="StyleSheetServlet" rel="stylesheet" type="text/css"/>
# <!-- -->
# <!-- Any title is fine                         -->
# <!-- -->
# <title>Event Entries</title>
# <!-- -->
# <!-- This script loads your compiled module.   -->
# <!-- If you add any GWT meta tags, they must   -->
# <!-- be added before this line.                -->
# <!-- -->
# ...

# %%
#!!go through html - find using BS [ull out urls for events, store in list]

#pull urls to be scaped 

# for url in urls:
#     events =[]
#     if 
    
# listings["headline"] = soup.find("a", class_="result-title").get_text()
# listings["price"] = soup.find("span", class_="result-price").get_text()
# listings["hood"] = soup.find("span", class_="result-hood").get_text()
#     return soup

# %%
#Get data from table 
table_divs = soup.find_all("div", class_='brd-shows')
for table_div in table_divs:
    first_row = table_div.find('tr')
    if 'Past Shows' in str(first_row):
        links = table_div.find_all('a')
        for link in links:
            requests.get("https://evententries.com/"+ 'link.href')
        print(links)
        
print('done')
#print(soup)

#List of all links
for row in rows:
   cells = row.find_all('td')
   if len(cells) > 1:
       rider_link = cells[1].find('a')
       print(rider_link.get('href'))
# Out:
# []
# done
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-40-8cdbc3a1bc87> in <module>
#      17    if len(cells) > 1:
#      18        rider_link = cells[1].find('a')
# ---> 19        print(rider_link.get('href'))
#
# AttributeError: 'NoneType' object has no attribute 'get'

# %%
#get links 

#List of all links
for row in rows:
   cells = row.find_all('td')
   if len(cells) > 1:
       rider_link = cells[1].find('a')
       print(rider_link.get('href'))
