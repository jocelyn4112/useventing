# %%
#Goal: pull url's from EE main page and click throughh them 

import requests
import lxml.html as lh
import pandas as pd
import numpy as np
import pandas as pd

from urllib.request import urlopen
from bs4 import BeautifulSoup
import codecs
from splinter import Browser
from bs4 import BeautifulSoup
import time

# %%
#Path to chromedriver
def init_browser():
    # @NOTE: Replace the path with your actual path to the chromedriver
    executable_path = {"executable_path": "chromedriver"}
    return Browser("chrome", **executable_path, headless=False)

# %%
#Scrape Event listings
def scrape():
    browser = init_browser()
    listings = {}

    url = "https://evententries.com/#LiveScores"
    browser.visit(url)
    time.sleep(2)
    html = browser.html
    soup = BeautifulSoup(html, "html.parser")
    return soup

# %%
soup = scrape()

# %%
#Html for main page 
print(soup)
# Out:
# <html><head>
# <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
# <meta content="width=device-width,initial-scale=1,maximum-scale=1,minimum-scale=1,user-scalable=no" name="viewport"/>
# <meta content="no-cache, no-store, must-revalidate" http-equiv="Cache-Control"/>
# <meta content="no-cache" http-equiv="Pragma"/>
# <meta content="0" http-equiv="Expires"/>
# <!-- -->
# <!-- Consider inlining CSS to reduce the number of requested files -->
# <!-- -->
# <link href="StyleSheetServlet" rel="stylesheet" type="text/css"/>
# <!-- -->
# <!-- Any title is fine                         -->
# <!-- -->
# <title>Event Entries</title>
# <!-- -->
# <!-- This script loads your compiled module.   -->
# <!-- If you add any GWT meta tags, they must   -->
# <!-- be added before this line.                -->
# <!-- -->
# ...

# %%
#Get data of indvidual events from table 
table_divs = soup.find_all("div", class_='brd-shows')
eventlink = []
for table_div in table_divs:
    first_row = table_div.find('tr')
    if 'Past Shows' in str(first_row):
        links = table_div.find_all('a')
        for link in links:
            #requests.get("https://evententries.com/"+ 'link.href')
            eventlink.append(link['href'])
print(eventlink)


#print('done')
#print(soup)

# #List of all links
# for row in rows:
#    cells = row.find_all('td')
#    if len(cells) > 1:
#        rider_link = cells[1].find('a')
#        print(rider_link.get('href'))
# Out:
# ['#LiveScoresUvswSaJj95W9wGr4Wfr0ew==', '#LiveScorescLq2_Z5ejBR_VFmRteuhaA==', '#LiveScoresKPEYoeEmPL7rM146HJ5z5A==', '#LiveScores$IRSdOwvqVXJK2le8gwSeA==', '#LiveScores_pGAtQsPZt0FQ4zn43EMKQ==', '#LiveScoresZ20dcHVvoSJOPk4LDgtYww==', '#LiveScores7xwnzhKWnzvVfjBZU1WGoA==', '#LiveScores_XFHzPJIXnBMlpRwk0dXXA==', '#LiveScores656qMXNCNPjB6r86TKAn9g==', '#LiveScores_LtFxbfrBhvIX0B6zrvH6g==', '#LiveScoresKyxFjPaRoJXFjLXTbMBOHQ==', '#LiveScoresczgCsdkIqAHEpUj5nDZMHA==', '#LiveScoresmYjNyGry03VHihtSYx5DaQ==', '#LiveScoresK$hl2Sygld8Ztq1EdcIWZQ==', '#LiveScoresAZUBx4ZsNTMnNhqpZm5X2g==', '#LiveScoresVMVm13PHdEVfttQAir95uA==', '#LiveScoreszlj$mhND8N1tNhprS3lpiA==', '#LiveScoresi5OtAuwpBqQVahyUYjHjZw==', '#LiveScoreszj0SvA48xLhWmSvMAbyt9A==', '#LiveScoresS48vUIDCWl8T7KGKZ7elFw==', '#LiveScoresyKkYArQRKSOOesU_QN2DvQ==', '#LiveScoresgOTUkBbgx_Yb11T9rJy1Yw==', '#LiveScoresP2tX8cl4zoMy704nAwkk5Q==', '#LiveScoresafZ1BBcLM7alcaUs$BA$Ow==', '#LiveScoresVxQGd9oe4RDaJ6PQ7$jZyA==', '#LiveScoresWJlhL4sD$S
# ...

# %%
#make a new for loop for the base url and get all of the live links 
for event in eventlink:
    link = "https://evententries.com/" + event
    print(link)
# Out:
# https://evententries.com/#LiveScoresUvswSaJj95W9wGr4Wfr0ew==
# https://evententries.com/#LiveScorescLq2_Z5ejBR_VFmRteuhaA==
# https://evententries.com/#LiveScoresKPEYoeEmPL7rM146HJ5z5A==
# https://evententries.com/#LiveScores$IRSdOwvqVXJK2le8gwSeA==
# https://evententries.com/#LiveScores_pGAtQsPZt0FQ4zn43EMKQ==
# https://evententries.com/#LiveScoresZ20dcHVvoSJOPk4LDgtYww==
# https://evententries.com/#LiveScores7xwnzhKWnzvVfjBZU1WGoA==
# https://evententries.com/#LiveScores_XFHzPJIXnBMlpRwk0dXXA==
# https://evententries.com/#LiveScores656qMXNCNPjB6r86TKAn9g==
# https://evententries.com/#LiveScores_LtFxbfrBhvIX0B6zrvH6g==
# https://evententries.com/#LiveScoresKyxFjPaRoJXFjLXTbMBOHQ==
# https://evententries.com/#LiveScoresczgCsdkIqAHEpUj5nDZMHA==
# https://evententries.com/#LiveScoresmYjNyGry03VHihtSYx5DaQ==
# https://evententries.com/#LiveScoresK$hl2Sygld8Ztq1EdcIWZQ==
# https://evententries.com/#LiveScoresAZUBx4ZsNTMnNhqpZm5X2g==
# ...

# %%
len(eventlink)
# Out:
# 442

# %%
#break into 10 links
eventlink1 = eventlink[20:]
print(eventlink1)
# Out:
# ['#LiveScoresyKkYArQRKSOOesU_QN2DvQ==', '#LiveScoresgOTUkBbgx_Yb11T9rJy1Yw==', '#LiveScoresP2tX8cl4zoMy704nAwkk5Q==', '#LiveScoresafZ1BBcLM7alcaUs$BA$Ow==', '#LiveScoresVxQGd9oe4RDaJ6PQ7$jZyA==', '#LiveScoresWJlhL4sD$SDXw11qo0aBhw==', '#LiveScoresMDi6S_SvpO3ImkmLHt5y3Q==', '#LiveScoresMlinbLDbe8h1TY_0JfHRdA==', '#LiveScoresn79k9DUPqfcXSCHuJrLUWQ==', '#LiveScoresMjCKcGCvmtByeA1vProK1Q==', '#LiveScoresiyNK2vtPiIrhel$dxyUjPA==', '#LiveScoresHBA0tK1XuqLjduYWmZycTw==', '#LiveScoresUKqt8tw1PqxBSzckdG$4Lw==', '#LiveScoresIgbGKNAhPUaHB7IrY6qXLA==', '#LiveScoresil1awW7SlSWarImkIhDTJA==', '#LiveScores06WVTwFfCU1mEZ1wyugSXw==', '#LiveScoresOd$6k5_3JkFd2QWI4iCr4A==', '#LiveScoresi587yDV$$wvXIbV$Ndh9Cw==', '#LiveScoresHC0MeaUQWmxlB9RH_tYPzA==', '#LiveScoreshd$gj72nTDP12LHUKU7TaQ==', '#LiveScoreswyOjIl1SS7xOApkvzQlFhA==', '#LiveScoresShGxQxDhVSBvYDrxb0Ihig==', '#LiveScores0yUTq3oqiYe13KeS94bBHQ==', '#LiveScorest1IMjtmXuiJnjzL$wm8BjA==', '#LiveScoresF_d35giWWEygqKy8nvh0zQ==', '#LiveScorescY5M_G1Ese
# ...

# %%
#Scrape Event listings - can add in any link and will return soup
def scrape(url):
    browser = init_browser()
    listings = {}

    browser.visit(url)
    time.sleep(2)
    html = browser.html
    soup = BeautifulSoup(html, "html.parser")
    return soup

# %%
#Scraped first 10 links
data_rows = []
for event in eventlink1:
    link = "https://evententries.com/" + event
    soup = scrape(link) 
    try:
        
    
        for div in soup.find_all('div', class_="brd-div"):
            table = div.find_next('table')
            # Now we have the table:
            # - the first row is the name of the trial
            # - the 2nd row is the "Last updated" row
            # - the 3rd row is the column headers
            # - all remaining rows are the data

            # Get the first row
            trial_row = table.find_next('tr')
            # Find the a tag and retrieve the inner text - this is the division name string
            division = trial_row.find_all('a')[0].text
            event = trial_row.find_all('a')[1].text

            # Get the next row (row 2)
            last_updated_row = trial_row.next_sibling
            # If you want the last updated time, pull it out here

            # Get the next row (row 3)
            col_header_row = last_updated_row.next_sibling
            # Iterate through the columns (td elements) in the row to extract the
            # column headers
            col_headers = []
            col_headers.append('Division')
            col_headers.append('Event')
            for td in col_header_row.find_all('td'):
                # The td elements we want have an inner div element with a class value
                # of gwt-HTML, the contents of that div are the label we want and the
                # label is split across two lines except the Rider/Horse column which
                # we need to treat as 2 separate columns

                if len(td.contents) == 3:
                    # This is the Rider/Horse td
                    col_headers.append(td.contents[0])
                    col_headers.append(td.contents[2])

                else:

                    inner_div = td.find('div', class_='gwt-HTML')
                    if inner_div:
                        label = inner_div.contents[0] + " " + inner_div.contents[2]
                        if label == 'Rider Horse':
                            col_headers += label.split(' ')
                        else:
                            col_headers.append(label)

            # Now iterate over the remaining rows in the table which contain the data
            # Every row contains a div with class gwt-HTML like the header row except
            # the Rider/Horse column which has 2 values separated by a <br/> tag

            for row in col_header_row.next_siblings:
                data_row = []
                data_row.append(division)
                data_row.append(event)
                for td in row.find_all('td'):
                    if len(td.contents) == 3:
                        # This is the Rider/Horse td
                        data_row.append(td.contents[0])
                        # The Horse name is wrapped in <i> tags so we get the contents
                        # of that inner tag
                        data_row.append(td.contents[2].contents[0])
                    else:
                        inner_div = td.find('div', class_='gwt-HTML')
                        if inner_div:
                            # The content of this div is the data value
                            data_row.append(inner_div.contents[0])
                data_rows.append(data_row)
    except:
        print(link)
    
df= pd.DataFrame.from_records(data_rows, columns=col_headers)
df.to_csv(f"{event}.csv", index=False)
# Out:
# https://evententries.com/#LiveScoresafZ1BBcLM7alcaUs$BA$Ow==
# https://evententries.com/#LiveScoresMDi6S_SvpO3ImkmLHt5y3Q==
# https://evententries.com/#LiveScoresil1awW7SlSWarImkIhDTJA==
# https://evententries.com/#LiveScoresOd$6k5_3JkFd2QWI4iCr4A==
# https://evententries.com/#LiveScorescY5M_G1EseBn$i3xmsxW9w==
# https://evententries.com/#LiveScores3ezC2pUklyDtLko4nqxYxA==
# https://evententries.com/#LiveScoresqEhDKc3LZLofhphlS6bBrQ==
# https://evententries.com/#LiveScoresr3SGhSESlrLBoQcvHhIT7A==
# https://evententries.com/#LiveScoresLx1x3T4bjSztgQnGQ_sagQ==
# https://evententries.com/#LiveScoresm8xfB5y8EViSTcFERahZpA==
# https://evententries.com/#LiveScores_UUb4$94mCDjcIpmWvIiMA==
# https://evententries.com/#LiveScoresXmmt5NTOTDTf4AbA8JKcVA==
# https://evententries.com/#LiveScorescf3Fw6QfC6ehbHbRTQPOfA==
# https://evententries.com/#LiveScoresdV$HRSBsPyqifsFFCGV$5w==
# https://evententries.com/#LiveScoresL6ml5yzBqq8Sk6yoa_kD8Q==
# ...
