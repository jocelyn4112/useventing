# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
# #URL of page 
# url = 'https://useventing.com/events-competitions/calendar'

# %%
# #retrieve page 
# response = requests.get(url)

# %%
# #Create beautiful soup object; parse with 'html.parser'
# soup = BeautifulSoup(response.text, 'html.parser')

# %%
for x in range(1,12):
    response = requests.get('https://services.useventing.com/API/GetUSEventingWebEventCalendarOmnibusListData?AppId=2AFE0073-4303-4671-AC37-CB5CC6ABF6D1&TokenId=DkSW_RWkYUWT3ILW0yYTQg&CalYear=&Area=' + str(x)).json()
    response = response['USEventingWebEventCalendarOmnibusListData']
    if x == 1:
        df = pd.DataFrame(response)
    else:
        new_df = pd.DataFrame(response)
        df = df.append(new_df)

# %%
df.to_csv('data.csv', index=False)

# %%
pd.read_csv('data.csv')
# Out:
#      EventID  EventDateDisplayRange  \
# 0      17621      APRIL 24-25, 2021
# 1      17629                  MAY 8
# 2      17636                 MAY 15
# 3      17652                 MAY 29
# 4      17660         JUNE 5-6, 2021
# ..       ...                    ...
# 252    17695         JULY 2-4, 2021
# 253    17701        JULY 8-10, 2021
# 254    17764  SEPTEMBER 25-26, 2021
# 255    17618     OCTOBER 9-10, 2021
# 256    17806   NOVEMBER 20-21, 2021
#
#                                                  Title  Area             City  \
# 0              University of New Hampshire Spring H.T.     1           Durham
# 1                                Apple Knoll Farm H.T.     1           Millis
# 2                              Hitching Post Farm H.T.     1   South Royalton
# 3                         Mystic Valley Hunt Club H.T.     1      Gales Ferry
# 4                                       GMHA June H.T.     1  South Woodstock
# ..                                                 ...   ...              ...
# 252                           Coconino Summer I H.T.      10        Flagstaff
# 253  Summer Coconino H.T and Western Underground, I...    10        Flagstaff
# 254  The Event at Isaacks Ranch - Pending USEF Appr...    10       Las Cruces
# 255                  St. Johns H.T. - Pending Approval    10      Saint Johns
# 256      Southern Arizona H.T. - Pending USEF Approval    10           Tucson
#
#     State    Zip   Begindate     Enddate   Opendate  ...  \
# 0      NH   3824   4/24/2021   4/25/2021   3/9/2021  ...
# 1      MA   2054    5/8/2021    5/8/2021  3/23/2021  ...
# 2      VT   5068   5/15/2021   5/15/2021  3/30/2021  ...
# 3      CT   6335   5/29/2021   5/29/2021  4/13/2021  ...
# 4      VT   5071    6/5/2021    6/6/2021  4/20/2021  ...
# ..    ...    ...         ...         ...        ...  ...
# 252    AZ  86001    7/2/2021    7/4/2021  5/18/2021  ...
# 253    AZ  86001    7/8/2021   7/10/2021  5/25/2021  ...
# 254    NM  88012   9/25/2021   9/26/2021  8/10/2021  ...
# 255    AZ  85936   10/9/2021  10/10/2021  8/24/2021  ...
# 256    AZ  85747  11/20/2021  11/21/2021  10/5/2021  ...
#
#             EventVenueAddress       EventVenueFacilityName   EventVenueCity  \
# 0               288 Mast Road            UNH Equine Center           Durham
# 1        1067 Old Sandwich Rd                 Valinor Farm         Plymouth
# 2         2096 Back River Rd.           Hitching Post Farm      S. Royalton
# 3            645 Long Cove Rd      Mystic Valley Hunt Club      Gales Ferry
# 4             5491 South Road                         GMHA  South Woodstock
# ..                        ...                          ...              ...
# 252  Fort TutHill Fairgrounds    Fort Tut Hill Fairgrounds        Flagstaff
# 253  Fort TutHill Fairgrounds    Fort Tut Hill Fairgrounds        Flagstaff
# 254         65 County Rd D-66                Isaacks Ranch       Las Cruces
# 255        845 W 4th N., St.   St. Johns Equestrian Center            Johns
# 256  Fort TutHill Fairgrounds    Fort Tut Hill Fairgrounds        Flagstaff
#
#      EventVenueState  EventVenueZip  XEntryStatus  \
# 0                 NH           3824         False
# 1                 MA           2360         False
# 2                 VT           5068         False
# 3                 CA           6335         False
# 4                 VT           5071         False
# ..               ...            ...           ...
# 252               AZ          86001         False
# 253               AZ          86001         False
# 254               NM          88012         False
# 255               AZ          85936         False
# 256               AZ          86001         False
#
#                                           EventWebsite UseaApprovalStatus  \
# 0    https://colsa.unh.edu/agriculture-nutrition-fo...           approved
# 1                           http://www.appleknoll.com/           approved
# 2                     http://www.hitchingpostfarm.com/           approved
# 3                       http://www.info@mvhchorse.com/           approved
# 4                               http://www.gmhainc.org           approved
# ..                                                 ...                ...
# 252                http://www.coconinohorsetrials.com/           approved
# 253                http://www.coconinohorsetrials.com/           approved
# 254                               www.isaacksranch.com           approved
# 255                 http://www.coconinohorsetrials.com           approved
# 256            http://www.southernarizonaeventing.org/           approved
#
#     FEIOpenDate FEICloseDate
# 0           NaN          NaN
# 1           NaN          NaN
# 2           NaN          NaN
# 3           NaN          NaN
# 4           NaN          NaN
# ..          ...          ...
# 252         NaN          NaN
# 253   5/25/2021    6/22/2021
# 254         NaN          NaN
# 255         NaN          NaN
# 256         NaN          NaN
#
# [257 rows x 27 columns]

# %%
df.columns
# Out:
# Index(['EventID', 'EventDateDisplayRange', 'Title', 'Area', 'City', 'State',
#        'Zip', 'Begindate', 'Enddate', 'Opendate', 'Closedate', 'SearchLevels',
#        'DisplayLevels', 'Result', 'Lon', 'Lat', 'ProvisionalCalendar',
#        'EventVenueAddress', 'EventVenueFacilityName', 'EventVenueCity',
#        'EventVenueState', 'EventVenueZip', 'XEntryStatus', 'EventWebsite',
#        'UseaApprovalStatus', 'FEIOpenDate', 'FEICloseDate'],
#       dtype='object')

# %%
df.tail()
# Out:
#   EventID  EventDateDisplayRange  \
# 2   17695         JULY 2-4, 2021
# 3   17701        JULY 8-10, 2021
# 4   17764  SEPTEMBER 25-26, 2021
# 5   17618     OCTOBER 9-10, 2021
# 6   17806   NOVEMBER 20-21, 2021
#
#                                                Title Area         City State  \
# 2                           Coconino Summer I H.T.     10    Flagstaff    AZ
# 3  Summer Coconino H.T and Western Underground, I...   10    Flagstaff    AZ
# 4  The Event at Isaacks Ranch - Pending USEF Appr...   10   Las Cruces    NM
# 5                  St. Johns H.T. - Pending Approval   10  Saint Johns    AZ
# 6      Southern Arizona H.T. - Pending USEF Approval   10       Tucson    AZ
#
#      Zip   Begindate     Enddate   Opendate  ...         EventVenueAddress  \
# 2  86001    7/2/2021    7/4/2021  5/18/2021  ...  Fort TutHill Fairgrounds
# 3  86001    7/8/2021   7/10/2021  5/25/2021  ...  Fort TutHill Fairgrounds
# 4  88012   9/25/2021   9/26/2021  8/10/2021  ...         65 County Rd D-66
# 5  85936   10/9/2021  10/10/2021  8/24/2021  ...        845 W 4th N., St.
# 6  85747  11/20/2021  11/21/2021  10/5/2021  ...  Fort TutHill Fairgrounds
#
#         EventVenueFacilityName EventVenueCity EventVenueState EventVenueZip  \
# 2    Fort Tut Hill Fairgrounds      Flagstaff              AZ         86001
# 3    Fort Tut Hill Fairgrounds      Flagstaff              AZ         86001
# 4                Isaacks Ranch     Las Cruces              NM         88012
# 5  St. Johns Equestrian Center          Johns              AZ         85936
# 6    Fort Tut Hill Fairgrounds      Flagstaff              AZ         86001
#
#   XEntryStatus                             EventWebsite UseaApprovalStatus  \
# 2        False      http://www.coconinohorsetrials.com/           approved
# 3        False      http://www.coconinohorsetrials.com/           approved
# 4        False                     www.isaacksranch.com           approved
# 5        False       http://www.coconinohorsetrials.com           approved
# 6        False  http://www.southernarizonaeventing.org/           approved
#
#   FEIOpenDate FEICloseDate
# 2
# 3   5/25/2021    6/22/2021
# 4
# 5
# 6
#
# [5 rows x 27 columns]

# %%
new_df = df[['EventID', 'EventDateDisplayRange', 'Title', 'Area', 'Lon', 'Lat',
       'EventVenueAddress', 'EventVenueFacilityName', 'EventVenueCity',
       'EventVenueState', 'EventVenueZip', 'EventWebsite']]

new_df
# Out:
#    EventID  EventDateDisplayRange  \
# 0    17621      APRIL 24-25, 2021
# 1    17629                  MAY 8
# 2    17636                 MAY 15
# 3    17652                 MAY 29
# 4    17660         JUNE 5-6, 2021
# ..     ...                    ...
# 2    17695         JULY 2-4, 2021
# 3    17701        JULY 8-10, 2021
# 4    17764  SEPTEMBER 25-26, 2021
# 5    17618     OCTOBER 9-10, 2021
# 6    17806   NOVEMBER 20-21, 2021
#
#                                                 Title Area           Lon  \
# 0             University of New Hampshire Spring H.T.    1    -70.939983
# 1                               Apple Knoll Farm H.T.    1    -70.572205
# 2                             Hitching Post Farm H.T.    1    -72.563259
# 3                        Mystic Valley Hunt Club H.T.    1    -72.040755
# 4                                      GMHA June H.T.    1    -72.539261
# ..                                                ...  ...           ...
# 2                            Coconino Summer I H.T.     10  -111.6929297
# 3   Summer Coconino H.T and Western Underground, I...   10  -111.6929297
# 4   The Event at Isaacks Ranch - Pending USEF Appr...   10   -106.698944
# 5                   St. Johns H.T. - Pending Approval   10   -109.373999
# 6       Southern Arizona H.T. - Pending USEF Approval   10  -111.6929297
#
#           Lat         EventVenueAddress       EventVenueFacilityName  \
# 0   43.142417             288 Mast Road            UNH Equine Center
# 1   41.861244      1067 Old Sandwich Rd                 Valinor Farm
# 2   43.810049       2096 Back River Rd.           Hitching Post Farm
# 3   41.404597          645 Long Cove Rd      Mystic Valley Hunt Club
# 4   43.557084           5491 South Road                         GMHA
# ..        ...                       ...                          ...
# 2   35.144368  Fort TutHill Fairgrounds    Fort Tut Hill Fairgrounds
# 3   35.144368  Fort TutHill Fairgrounds    Fort Tut Hill Fairgrounds
# 4   32.452377         65 County Rd D-66                Isaacks Ranch
# 5    34.51151        845 W 4th N., St.   St. Johns Equestrian Center
# 6   35.144368  Fort TutHill Fairgrounds    Fort Tut Hill Fairgrounds
#
#      EventVenueCity EventVenueState EventVenueZip  \
# 0            Durham              NH          3824
# 1          Plymouth              MA          2360
# 2       S. Royalton              VT          5068
# 3       Gales Ferry              CA          6335
# 4   South Woodstock              VT          5071
# ..              ...             ...           ...
# 2         Flagstaff              AZ         86001
# 3         Flagstaff              AZ         86001
# 4        Las Cruces              NM         88012
# 5             Johns              AZ         85936
# 6         Flagstaff              AZ         86001
#
#                                          EventWebsite
# 0   https://colsa.unh.edu/agriculture-nutrition-fo...
# 1                          http://www.appleknoll.com/
# 2                    http://www.hitchingpostfarm.com/
# 3                      http://www.info@mvhchorse.com/
# 4                              http://www.gmhainc.org
# ..                                                ...
# 2                 http://www.coconinohorsetrials.com/
# 3                 http://www.coconinohorsetrials.com/
# 4                                www.isaacksranch.com
# 5                  http://www.coconinohorsetrials.com
# 6             http://www.southernarizonaeventing.org/
#
# [257 rows x 12 columns]
